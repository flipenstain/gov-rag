# %%
from neo4j import GraphDatabase
 
# Define correct URI and AUTH arguments (no AUTH by default)
URI = "bolt://localhost:7687"
AUTH = ("", "")
 
with GraphDatabase.driver(URI, auth=AUTH) as client:
    # Check the connection
    client.verify_connectivity()
 
    # Find a user John in the database
    records, summary, keys = client.execute_query(
        "CALL export_util.json('/usr/lib/memgraph/query_modules/export.json') YIELD objects return objects;",
        database_="memgraph",
    )
 
    # Get the result
    for record in records:
        print(record["name"])
 
    # Print the query
    print(summary.query)

# %%
def restructure_json_list(data_list):
    """
    Restructures a list of JSON-like dictionaries to group relationships by the 'relationship' key.

    Args:
        data_list: A list of dictionaries, where each dictionary contains a 'relationship' key.

    Returns:
        A dictionary where the 'relationship' key maps to a list of relationship dictionaries.
    """
    if not isinstance(data_list, list):
      return data_list #raise TypeError("Input must be a list")

    nodes = []
    for item in data_list:
        if isinstance(item, dict) and 'node' in item and isinstance(item['node'], dict):
            node = item['node'].copy()  # Create a copy to avoid modifying the original
            if 'name' in node:
                node['id'] = node.pop('name')  # Rename 'name' to 'id'
            nodes.append(node)

    #return {"nodes": nodes}

    relationships = []
    for item in data_list:
        if isinstance(item, dict) and 'relationship' in item and isinstance(item['relationship'], dict):
            relationships.append(item['relationship'])
        #if you have other keys in the original list, you can add more elif statements here.

    return {"nodes": nodes,
        "relationships": relationships}

# %%
def transform_nodes(nodes_list):
    """
    Transforms a list of node dictionaries from the given format to {'id': '...', 'type': '...'}.

    Args:
        nodes_list: A list of node dictionaries.

    Returns:
        A list of transformed node dictionaries.
    """
    if not isinstance(nodes_list, list):
      raise TypeError("Input must be a list")

    transformed_nodes = []
    for node in nodes_list:
        if isinstance(node, dict) and 'id' in node and 'labels' in node and isinstance(node['labels'], list) and len(node['labels']) > 0:
            transformed_node = {'id': node['id'], 'type': node['labels'][0].replace(" ", "")} #remove spaces in the type name.
            transformed_nodes.append(transformed_node)
        #if you have other node formats, add elif statements here.
        else:
            transformed_nodes.append(node)
    return transformed_nodes

# %%
from neo4j import GraphDatabase
import json

# Define connection details
URI = "bolt://localhost:7687"
AUTH = ("", "")  # No authentication for Memgraph

# Load JSON data from a file
def load_json_from_file(filename):
    with open(filename, "r", encoding="utf-8") as file:
        print("Opening file: ", filename)
        return json.load(file)

# Function to load data into Memgraph
def load_graph_from_json(json_data):
    with GraphDatabase.driver(URI, auth=AUTH) as client:
        client.verify_connectivity()
        json_data = restructure_json_list(json_data)

        

        # Create Nodes
        for node in transform_nodes(json_data["nodes"]):
            query = """
            MERGE (n:$type {id: $id})
            RETURN n.id AS name;
            """
            
            records, _, _ = client.execute_query(query, type=node["type"], id=node["id"], database_="memgraph")

            # Print created nodes
            for record in records:
                print("Created node:", record["name"])

        # Create Relationships
        for rel in transform_nodes(json_data["relationships"]):
            source = rel["source"]
            target = rel["target"]
            relation = rel["relation"]

            query = f"""
            MATCH (s {{id: $source}}), (t {{id: $target}})
            MERGE (s)-[r:{relation}]->(t)
            RETURN type(r) AS relation;
            """
            
            print("Executing Query:", query)  # Debugging output
            
            records, _, _ = client.execute_query(
                query, source=source, target=target, database_="memgraph"
            )

            # Print created relationships
            for record in records:
                print("Created relationship:", record["relation"])

# Load JSON from file and insert it into Memgraph
#json_filename = "answer_from_LLM.json"  # Replace with your actual file path
#json_data = load_json_from_file(json_filename)
#load_graph_from_json(json_data)

# %%
import os

llm_answers_path = r"LLM_answers"
json_files = [f for f in os.listdir(llm_answers_path) if f.endswith(".json")]


for filename in json_files:
    llm_json_path = os.path.join(llm_answers_path, filename)
    json_data = load_json_from_file(llm_json_path)
    load_graph_from_json(json_data)
# Out:
# Opening file:  LLM_answers\answer_20250305_022711.json
# Created node: ProspectIncremental
# Created node: wh_db_stage
# Created node: agencyid
# Created node: lastname
# Created node: firstname
# Created node: middleinitial
# Created node: gender
# Created node: addressline1
# Created node: addressline2
# Created node: postalcode
# Created node: city
# Created node: state
# Created node: country
# Created node: phone
# Created node: income
# Created node: numbercars
# Created node: numberchildren
# Created node: maritalstatus
# Created node: age
# Created node: creditrating
# Created node: ownorrentflag
# Created node: employer
# Created node: numbercreditcards
# Created node: networth
# Created node: marketingnameplate
# Created node: recordbatchid
# Created node: Unique identifier from agency
# Created node: Last name
# Created node: First name
# Created node: Middle initial
# Created node: â€˜Mâ€™ or â€˜Fâ€™ or â€˜Uâ€™
# Created node: Postal address
# Created node: Postal address
# Created node: Postal code
# Created node: City
# Created node: State or province
# Created node: Postal country
# Created node: Telephone number
# Created node: Annual income
# Created node: Cars owned
# Created node: Dependent children
# Created node: â€˜Sâ€™ or â€˜Mâ€™ or â€˜Dâ€™ or â€˜Wâ€™ or â€˜Uâ€™
# Created node: Current age
# Created node: Numeric rating
# Created node: â€˜Oâ€™ or â€˜Râ€™ or â€˜Uâ€™
# Created node: Name of employer
# Created node: Credit cards
# Created node: Estimated total net worth
# Created node: Marketing nameplate
# Created node: Batch ID when this record last inserted
# Created node: ProspectIncremental table contains prospect data.
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Opening file:  LLM_answers\answer_20250305_022715.json
# Created node: batchdate
# Created node: BatchDate
# Created node: DATE
# Created node: wh_db
# Created node: Batch date
# Created node: batchid
# Created node: INT
# Created node: Batch ID when this record was inserted
# Created node: Contains batch processing dates and IDs.
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Opening file:  LLM_answers\answer_20250305_022724.json
# Created node: wh_db.DimAccount
# Created node: wh_db
# Created node: sk_accountid
# Created node: accountid
# Created node: sk_brokerid
# Created node: sk_customerid
# Created node: accountdesc
# Created node: taxstatus
# Created node: status
# Created node: iscurrent
# Created node: batchid
# Created node: effectivedate
# Created node: enddate
# Created node: BIGINT
# Created node: STRING
# Created node: TINYINT
# Created node: BOOLEAN
# Created node: INT
# Created node: DATE
# Created node: Surrogate key for AccountID
# Created node: Customer account identifier
# Created node: Surrogate key of managing broker
# Created node: Surrogate key of customer
# Created node: Name of customer account
# Created node: Tax status of this account
# Created node: Account status, active or closed
# Created node: True if this is the current record
# Created node: Batch ID when this record was inserted
# Created node: Beginning of date range when this record was the current record
# Created node: Ending of date range when this record was the current record. A record that is not expired will use the date 9999-12-31.
# Created node: Dimension table containing account information
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Opening file:  LLM_answers\answer_20250305_022736.json
# Created node: sk_brokerid
# Created node: DimBroker
# Created node: BIGINT
# Created node: wh_db
# Created node: brokerid
# Created node: BIGINT
# Created node: managerid
# Created node: BIGINT
# Created node: firstname
# Created node: STRING
# Created node: lastname
# Created node: STRING
# Created node: middleinitial
# Created node: STRING
# Created node: branch
# Created node: STRING
# Created node: office
# Created node: STRING
# Created node: phone
# Created node: STRING
# Created node: iscurrent
# Created node: BOOLEAN
# Created node: batchid
# Created node: INT
# Created node: effectivedate
# Created node: DATE
# Created node: enddate
# Created node: DATE
# Created node: Surrogate key for broker
# Created node: Natural key for broker
# Created node: Natural key for managerâ€™s HR record
# Created node: First name
# Created node: Last Name
# Created node: Middle initial
# Created node: Facility in which employee has office
# Created node: Office number or description
# Created node: Employee phone number
# Created node: True if this is the current record
# Created node: Batch ID when this record was inserted
# Created node: Beginning of date range when this record was the current record
# Created node: Ending of date range when this record was the current record. A record that is not expired will use the date 9999-12-31.
# Created node: Stores information about brokers
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Opening file:  LLM_answers\answer_20250305_022750.json
# Created node: sk_companyid
# Created node: DimCompany
# Created node: BIGINT
# Created node: wh_db
# Created node: Surrogate key for CompanyID
# Created node: companyid
# Created node: Company identifier (CIK number)
# Created node: status
# Created node: STRING
# Created node: Company status
# Created node: name
# Created node: Company name
# Created node: industry
# Created node: Companyâ€™s industry
# Created node: sprating
# Created node: Standard & Poor companyâ€™s rating
# Created node: islowgrade
# Created node: BOOLEAN
# Created node: True if this company is low grade
# Created node: ceo
# Created node: CEO name
# Created node: addressline1
# Created node: Address Line 1
# Created node: addressline2
# Created node: Address Line 2
# Created node: postalcode
# Created node: Zip or postal code
# Created node: city
# Created node: City
# Created node: stateprov
# Created node: State or Province
# Created node: country
# Created node: Country
# Created node: description
# Created node: Company description
# Created node: foundingdate
# Created node: DATE
# Created node: Date the company was founded
# Created node: iscurrent
# Created node: True if this is the current record
# Created node: batchid
# Created node: INT
# Created node: Batch ID when this record was inserted
# Created node: effectivedate
# Created node: Beginning of date range when this record was the current record
# Created node: enddate
# Created node: Ending of date range when this record was the current record. A record that is not expired will use the date 9999-12-31.
# Created node: Dimension table containing company information
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Opening file:  LLM_answers\answer_20250305_022811.json
# Opening file:  LLM_answers\answer_20250305_022828.json
# Created node: sk_dateid
# Created node: DimDate
# Created node: BIGINT
# Created node: wh_db
# Created node: Surrogate key for the date
# Created node: datevalue
# Created node: DATE
# Created node: The date stored appropriately for doing comparisons in the Data Warehouse
# Created node: datedesc
# Created node: STRING
# Created node: The date in full written form e.g. July 7 2004
# Created node: calendaryearid
# Created node: INT
# Created node: Year number as a number
# Created node: calendaryeardesc
# Created node: STRING
# Created node: Year number as text
# Created node: calendarqtrid
# Created node: INT
# Created node: Quarter as a number e.g. 20042
# Created node: calendarqtrdesc
# Created node: STRING
# Created node: Quarter as text e.g. 2004 Q2
# Created node: calendarmonthid
# Created node: INT
# Created node: Month as a number e.g. 20047
# Created node: calendarmonthdesc
# Created node: STRING
# Created node: Month as text e.g. 2004 July
# Created node: calendarweekid
# Created node: INT
# Created node: Week as a number e.g. 200428
# Created node: calendarweekdesc
# Created node: STRING
# Created node: Week as text e.g. 2004-W28
# Created node: dayofweeknum
# Created node: INT
# Created node: Day of week as a number e.g. 3
# Created node: dayofweekdesc
# Created node: STRING
# Created node: Day of week as text e.g. Wednesday
# Created node: fiscalyearid
# Created node: INT
# Created node: Fiscal year as a number e.g. 2005
# Created node: fiscalyeardesc
# Created node: STRING
# Created node: Fiscal year as text e.g. 2005
# Created node: fiscalqtrid
# Created node: INT
# Created node: Fiscal quarter as a number e.g. 20051
# Created node: fiscalqtrdesc
# Created node: STRING
# Created node: Fiscal quarter as text e.g. 2005 Q1
# Created node: holidayflag
# Created node: BOOLEAN
# Created node: Indicates holidays
# Created node: Stores date dimension information
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
# ...
# Created node: numbercars
# Created node: INT
# Created node: Cars owned
# Created node: numberchildren
# Created node: Dependent children
# Created node: maritalstatus
# Created node: â€˜Sâ€™ or â€˜Mâ€™ or â€˜Dâ€™ or â€˜Wâ€™ or â€˜Uâ€™
# Created node: age
# Created node: Current age
# Created node: creditrating
# Created node: Numeric rating
# Created node: ownorrentflag
# Created node: â€˜Oâ€™ or â€˜Râ€™ or â€˜Uâ€™
# Created node: employer
# Created node: Name of employer
# Created node: numbercreditcards
# Created node: Credit cards
# Created node: networth
# Created node: Estimated total net worth
# Created node: marketingnameplate
# Created node: Marketing nameplate
# Created node: recordbatchid
# Created node: Batch ID when this record last inserted
# Created node: Table containing incremental prospect data
# Created node: Postal address
# Created node: batchid
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF

# %%
asd = load_json_from_file(r"LLM_answers\answer_20250305_022936.json")
asd2 = load_json_from_file(r"LLM_answers\answer_20250305_022947.json")
# Out:
# Opening file:  LLM_answers\answer_20250305_022936.json
# Opening file:  LLM_answers\answer_20250305_022947.json

# %%
asd["nodes"]
# Out:
# [{'id': 'wh_db.FactWatches',
#   'labels': ['TableName'],
#   'properties': {'name': 'wh_db.FactWatches'}},
#  {'id': 'sk_customerid',
#   'labels': ['ColumnName'],
#   'properties': {'name': 'sk_customerid'}},
#  {'id': 'sk_securityid',
#   'labels': ['ColumnName'],
#   'properties': {'name': 'sk_securityid'}},
#  {'id': 'sk_dateid_dateplaced',
#   'labels': ['ColumnName'],
#   'properties': {'name': 'sk_dateid_dateplaced'}},
#  {'id': 'sk_dateid_dateremoved',
#   'labels': ['ColumnName'],
#   'properties': {'name': 'sk_dateid_dateremoved'}},
#  {'id': 'batchid',
#   'labels': ['ColumnName'],
#   'properties': {'name': 'batchid'}},
#  {'id': 'BIGINT', 'labels': ['Data Type'], 'properties': {'name': 'BIGINT'}},
#  {'id': 'INT', 'labels': ['Data Type'], 'properties': {'name': 'INT'}},
#  {'id': 'wh_db', 'labels': ['SchemaName'], 'properties': {'name': 'wh_db'}},
#  {'id': 'Customer associated with watch list',
#   'labels': ['Comment'],
#   'properties': {'text': 'Customer associated with watch list'}},
#  {'id': 'Security listed on watch list',
#   'labels': ['Comment'],
#   'properties': {'text': 'Security listed on watch list'}},
#  {'id': 'Date the watch list item was added',
#   'labels': ['Comment'],
#   'properties': {'text': 'Date the watch list item was added'}},
#  {'id': 'Date the watch list item was removed',
#   'labels': ['Comment'],
#   'properties': {'text': 'Date the watch list item was removed'}},
#  {'id': 'Batch ID when this record was inserted',
#   'labels': ['Comment'],
#   'properties': {'text': 'Batch ID when this record was inserted'}},
#  {'id': 'FactWatches stores watch list information',
#   'labels': ['Summary'],
#   'properties': {'text': 'FactWatches stores watch list information'}}]

# %%
def transform_nodes(nodes_list):
    """
    Transforms a list of node dictionaries from the given format to {'id': '...', 'type': '...'}.

    Args:
        nodes_list: A list of node dictionaries.

    Returns:
        A list of transformed node dictionaries.
    """
    if not isinstance(nodes_list, list):
      raise TypeError("Input must be a list")

    transformed_nodes = []
    for node in nodes_list:
        if isinstance(node, dict) and 'id' in node and 'labels' in node and isinstance(node['labels'], list) and len(node['labels']) > 0:
            transformed_node = {'id': node['id'], 'type': node['labels'][0].replace(" ", "")} #remove spaces in the type name.
            transformed_nodes.append(transformed_node)
        #if you have other node formats, add elif statements here.
        else:
            transformed_nodes.append(node)
    return transformed_nodes

# %%
transform_nodes(asd2["nodes"])
# Out:
# [{'id': 'sk_companyid', 'type': 'ColumnName'},
#  {'id': 'Financial', 'type': 'TableName'},
#  {'id': 'BIGINT', 'type': 'Data Type'},
#  {'id': 'wh_db', 'type': 'SchemaName'},
#  {'id': 'Company SK.', 'type': 'Comment'},
#  {'id': 'fi_year', 'type': 'ColumnName'},
#  {'id': 'INT', 'type': 'Data Type'},
#  {'id': 'Year of the quarter end.', 'type': 'Comment'},
#  {'id': 'fi_qtr', 'type': 'ColumnName'},
#  {'id': 'Quarter number that the financial information is for: valid values 1, 2, 3, 4.',
#   'type': 'Comment'},
#  {'id': 'fi_qtr_start_date', 'type': 'ColumnName'},
#  {'id': 'DATE', 'type': 'Data Type'},
#  {'id': 'Start date of quarter.', 'type': 'Comment'},
#  {'id': 'fi_revenue', 'type': 'ColumnName'},
#  {'id': 'DOUBLE', 'type': 'Data Type'},
#  {'id': 'Reported revenue for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_net_earn', 'type': 'ColumnName'},
#  {'id': 'Net earnings reported for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_basic_eps', 'type': 'ColumnName'},
#  {'id': 'Basic earnings per share for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_dilut_eps', 'type': 'ColumnName'},
#  {'id': 'Diluted earnings per share for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_margin', 'type': 'ColumnName'},
#  {'id': 'Profit divided by revenues for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_inventory', 'type': 'ColumnName'},
#  {'id': 'Value of inventory on hand at the end of quarter.',
#   'type': 'Comment'},
#  {'id': 'fi_assets', 'type': 'ColumnName'},
#  {'id': 'Value of total assets at the end of the quarter.', 'type': 'Comment'},
#  {'id': 'fi_liability', 'type': 'ColumnName'},
#  {'id': 'Value of total liabilities at the end of the quarter.',
#   'type': 'Comment'},
#  {'id': 'fi_out_basic', 'type': 'ColumnName'},
#  {'id': 'Average number of shares outstanding (basic).', 'type': 'Comment'},
#  {'id': 'fi_out_dilut', 'type': 'ColumnName'},
#  {'id': 'Average number of shares outstanding (diluted).', 'type': 'Comment'},
#  {'id': 'Financial data for companies', 'type': 'Summary'}]

# %%
def restructure_and_rename_nodes(data_list):
    """
    Restructures a list of JSON-like dictionaries to group nodes by the 'node' key,
    renames 'name' to 'id', and returns a dictionary with 'nodes' as the key.

    Args:
        data_list: A list of dictionaries, where each dictionary contains a 'node' key.

    Returns:
        A dictionary where the 'nodes' key maps to a list of node dictionaries with 'id' instead of 'name'.
    """
    if not isinstance(data_list, list):
      return data_list # raise TypeError("Input must be a list")

    nodes = []
    for item in data_list:
        if isinstance(item, dict) and 'node' in item and isinstance(item['node'], dict):
            node = item['node'].copy()  # Create a copy to avoid modifying the original
            if 'name' in node:
                node['id'] = node.pop('name')  # Rename 'name' to 'id'
            nodes.append(node)

    return {"nodes": nodes}

restructure_and_rename_nodes(asd)
# Out:
# {'nodes': [{'type': 'TableName', 'id': 'ProspectIncremental'},
#   {'type': 'SchemaName', 'id': 'wh_db_stage'},
#   {'type': 'ColumnName', 'id': 'agencyid'},
#   {'type': 'ColumnName', 'id': 'lastname'},
#   {'type': 'ColumnName', 'id': 'firstname'},
#   {'type': 'ColumnName', 'id': 'middleinitial'},
#   {'type': 'ColumnName', 'id': 'gender'},
#   {'type': 'ColumnName', 'id': 'addressline1'},
#   {'type': 'ColumnName', 'id': 'addressline2'},
#   {'type': 'ColumnName', 'id': 'postalcode'},
#   {'type': 'ColumnName', 'id': 'city'},
#   {'type': 'ColumnName', 'id': 'state'},
#   {'type': 'ColumnName', 'id': 'country'},
#   {'type': 'ColumnName', 'id': 'phone'},
#   {'type': 'ColumnName', 'id': 'income'},
#   {'type': 'ColumnName', 'id': 'numbercars'},
#   {'type': 'ColumnName', 'id': 'numberchildren'},
#   {'type': 'ColumnName', 'id': 'maritalstatus'},
#   {'type': 'ColumnName', 'id': 'age'},
#   {'type': 'ColumnName', 'id': 'creditrating'},
#   {'type': 'ColumnName', 'id': 'ownorrentflag'},
#   {'type': 'ColumnName', 'id': 'employer'},
#   {'type': 'ColumnName', 'id': 'numbercreditcards'},
#   {'type': 'ColumnName', 'id': 'networth'},
#   {'type': 'ColumnName', 'id': 'marketingnameplate'},
#   {'type': 'ColumnName', 'id': 'recordbatchid'},
#   {'type': 'Comment', 'id': 'Unique identifier from agency'},
#   {'type': 'Comment', 'id': 'Last name'},
#   {'type': 'Comment', 'id': 'First name'},
#   {'type': 'Comment', 'id': 'Middle initial'},
#   {'type': 'Comment', 'id': 'â€˜Mâ€™ or â€˜Fâ€™ or â€˜Uâ€™'},
#   {'type': 'Comment', 'id': 'Postal address'},
#   {'type': 'Comment', 'id': 'Postal address'},
#   {'type': 'Comment', 'id': 'Postal code'},
#   {'type': 'Comment', 'id': 'City'},
#   {'type': 'Comment', 'id': 'State or province'},
#   {'type': 'Comment', 'id': 'Postal country'},
#   {'type': 'Comment', 'id': 'Telephone number'},
#   {'type': 'Comment', 'id': 'Annual income'},
#   {'type': 'Comment', 'id': 'Cars owned'},
#   {'type': 'Comment', 'id': 'Dependent children'},
#   {'type': 'Comment',
#    'id': 'â€˜Sâ€™ or â€˜Mâ€™ or â€˜Dâ€™ or â€˜Wâ€™ or â€˜Uâ€™'},
#   {'type': 'Comment', 'id': 'Current age'},
#   {'type': 'Comment', 'id': 'Numeric rating'},
#   {'type': 'Comment', 'id': 'â€˜Oâ€™ or â€˜Râ€™ or â€˜Uâ€™'},
#   {'type': 'Comment', 'id': 'Name of employer'},
#   {'type': 'Comment', 'id': 'Credit cards'},
#   {'type': 'Comment', 'id': 'Estimated total net worth'},
#   {'type': 'Comment', 'id': 'Marketing nameplate'},
#   {'type': 'Comment', 'id': 'Batch ID when this record last inserted'},
#   {'type': 'Summary',
#    'id': 'ProspectIncremental table contains prospect data.'}]}

# %%
def restructure_json_list(data_list):
    """
    Restructures a list of JSON-like dictionaries to group relationships by the 'relationship' key.

    Args:
        data_list: A list of dictionaries, where each dictionary contains a 'relationship' key.

    Returns:
        A dictionary where the 'relationship' key maps to a list of relationship dictionaries.
    """
    if not isinstance(data_list, list):
      return data_list #raise TypeError("Input must be a list")

    nodes = []
    for item in data_list:
        if isinstance(item, dict) and 'node' in item and isinstance(item['node'], dict):
            node = item['node'].copy()  # Create a copy to avoid modifying the original
            if 'name' in node:
                node['id'] = node.pop('name')  # Rename 'name' to 'id'
            nodes.append(node)

    #return {"nodes": nodes}

    relationships = []
    for item in data_list:
        if isinstance(item, dict) and 'relationship' in item and isinstance(item['relationship'], dict):
            relationships.append(item['relationship'])
        #if you have other keys in the original list, you can add more elif statements here.

    return {"nodes": nodes,
        "relationships": relationships}


restructured_data = restructure_json_list(asd2)

restructured_data
# Out:
# {'nodes': [{'id': 'sk_companyid', 'type': 'ColumnName'},
#   {'id': 'Financial', 'type': 'TableName'},
#   {'id': 'BIGINT', 'type': 'Data Type'},
#   {'id': 'wh_db', 'type': 'SchemaName'},
#   {'id': 'Company SK.', 'type': 'Comment'},
#   {'id': 'fi_year', 'type': 'ColumnName'},
#   {'id': 'INT', 'type': 'Data Type'},
#   {'id': 'Year of the quarter end.', 'type': 'Comment'},
#   {'id': 'fi_qtr', 'type': 'ColumnName'},
#   {'id': 'Quarter number that the financial information is for: valid values 1, 2, 3, 4.',
#    'type': 'Comment'},
#   {'id': 'fi_qtr_start_date', 'type': 'ColumnName'},
#   {'id': 'DATE', 'type': 'Data Type'},
#   {'id': 'Start date of quarter.', 'type': 'Comment'},
#   {'id': 'fi_revenue', 'type': 'ColumnName'},
#   {'id': 'DOUBLE', 'type': 'Data Type'},
#   {'id': 'Reported revenue for the quarter.', 'type': 'Comment'},
#   {'id': 'fi_net_earn', 'type': 'ColumnName'},
#   {'id': 'Net earnings reported for the quarter.', 'type': 'Comment'},
#   {'id': 'fi_basic_eps', 'type': 'ColumnName'},
#   {'id': 'Basic earnings per share for the quarter.', 'type': 'Comment'},
#   {'id': 'fi_dilut_eps', 'type': 'ColumnName'},
#   {'id': 'Diluted earnings per share for the quarter.', 'type': 'Comment'},
#   {'id': 'fi_margin', 'type': 'ColumnName'},
#   {'id': 'Profit divided by revenues for the quarter.', 'type': 'Comment'},
#   {'id': 'fi_inventory', 'type': 'ColumnName'},
#   {'id': 'Value of inventory on hand at the end of quarter.',
#    'type': 'Comment'},
#   {'id': 'fi_assets', 'type': 'ColumnName'},
#   {'id': 'Value of total assets at the end of the quarter.',
#    'type': 'Comment'},
#   {'id': 'fi_liability', 'type': 'ColumnName'},
#   {'id': 'Value of total liabilities at the end of the quarter.',
#    'type': 'Comment'},
#   {'id': 'fi_out_basic', 'type': 'ColumnName'},
#   {'id': 'Average number of shares outstanding (basic).', 'type': 'Comment'},
#   {'id': 'fi_out_dilut', 'type': 'ColumnName'},
#   {'id': 'Average number of shares outstanding (diluted).', 'type': 'Comment'},
#   {'id': 'Financial data for companies', 'type': 'Summary'}],
#  'relationships': [{'source': 'sk_companyid',
#    'target': 'Financial',
#    'relation': 'PART_OF'},
#   {'source': 'sk_companyid', 'target': 'BIGINT', 'relation': 'TYPE_OF'},
#   {'source': 'Financial', 'target': 'wh_db', 'relation': 'PART_OF'},
#   {'source': 'Company SK.', 'target': 'sk_companyid', 'relation': 'DESCRIBES'},
#   {'source': 'fi_year', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_year', 'target': 'INT', 'relation': 'TYPE_OF'},
#   {'source': 'Year of the quarter end.',
#    'target': 'fi_year',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_qtr', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_qtr', 'target': 'INT', 'relation': 'TYPE_OF'},
#   {'source': 'Quarter number that the financial information is for: valid values 1, 2, 3, 4.',
#    'target': 'fi_qtr',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_qtr_start_date',
#    'target': 'Financial',
#    'relation': 'PART_OF'},
#   {'source': 'fi_qtr_start_date', 'target': 'DATE', 'relation': 'TYPE_OF'},
#   {'source': 'Start date of quarter.',
#    'target': 'fi_qtr_start_date',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_revenue', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_revenue', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Reported revenue for the quarter.',
#    'target': 'fi_revenue',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_net_earn', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_net_earn', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Net earnings reported for the quarter.',
#    'target': 'fi_net_earn',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_basic_eps', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_basic_eps', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Basic earnings per share for the quarter.',
#    'target': 'fi_basic_eps',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_dilut_eps', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_dilut_eps', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Diluted earnings per share for the quarter.',
#    'target': 'fi_dilut_eps',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_margin', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_margin', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Profit divided by revenues for the quarter.',
#    'target': 'fi_margin',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_inventory', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_inventory', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Value of inventory on hand at the end of quarter.',
#    'target': 'fi_inventory',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_assets', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_assets', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Value of total assets at the end of the quarter.',
#    'target': 'fi_assets',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_liability', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_liability', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Value of total liabilities at the end of the quarter.',
#    'target': 'fi_liability',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_out_basic', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_out_basic', 'target': 'BIGINT', 'relation': 'TYPE_OF'},
#   {'source': 'Average number of shares outstanding (basic).',
#    'target': 'fi_out_basic',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_out_dilut', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_out_dilut', 'target': 'BIGINT', 'relation': 'TYPE_OF'},
#   {'source': 'Average number of shares outstanding (diluted).',
#    'target': 'fi_out_dilut',
#    'relation': 'DESCRIBES'},
#   {'source': 'Financial data for companies',
#    'target': 'Financial',
#    'relation': 'DESCRIBES'}]}

# %%
restructured_data = restructure_json_list(asd2)

restructured_data["nodes"]
# Out:
# [{'id': 'sk_companyid', 'type': 'ColumnName'},
#  {'id': 'Financial', 'type': 'TableName'},
#  {'id': 'BIGINT', 'type': 'Data Type'},
#  {'id': 'wh_db', 'type': 'SchemaName'},
#  {'id': 'Company SK.', 'type': 'Comment'},
#  {'id': 'fi_year', 'type': 'ColumnName'},
#  {'id': 'INT', 'type': 'Data Type'},
#  {'id': 'Year of the quarter end.', 'type': 'Comment'},
#  {'id': 'fi_qtr', 'type': 'ColumnName'},
#  {'id': 'Quarter number that the financial information is for: valid values 1, 2, 3, 4.',
#   'type': 'Comment'},
#  {'id': 'fi_qtr_start_date', 'type': 'ColumnName'},
#  {'id': 'DATE', 'type': 'Data Type'},
#  {'id': 'Start date of quarter.', 'type': 'Comment'},
#  {'id': 'fi_revenue', 'type': 'ColumnName'},
#  {'id': 'DOUBLE', 'type': 'Data Type'},
#  {'id': 'Reported revenue for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_net_earn', 'type': 'ColumnName'},
#  {'id': 'Net earnings reported for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_basic_eps', 'type': 'ColumnName'},
#  {'id': 'Basic earnings per share for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_dilut_eps', 'type': 'ColumnName'},
#  {'id': 'Diluted earnings per share for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_margin', 'type': 'ColumnName'},
#  {'id': 'Profit divided by revenues for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_inventory', 'type': 'ColumnName'},
#  {'id': 'Value of inventory on hand at the end of quarter.',
#   'type': 'Comment'},
#  {'id': 'fi_assets', 'type': 'ColumnName'},
#  {'id': 'Value of total assets at the end of the quarter.', 'type': 'Comment'},
#  {'id': 'fi_liability', 'type': 'ColumnName'},
#  {'id': 'Value of total liabilities at the end of the quarter.',
#   'type': 'Comment'},
#  {'id': 'fi_out_basic', 'type': 'ColumnName'},
#  {'id': 'Average number of shares outstanding (basic).', 'type': 'Comment'},
#  {'id': 'fi_out_dilut', 'type': 'ColumnName'},
#  {'id': 'Average number of shares outstanding (diluted).', 'type': 'Comment'},
#  {'id': 'Financial data for companies', 'type': 'Summary'}]

# %%
for rel in json_data["relationships"]:
    source = rel["source"]
    target = rel["target"]
    relation = rel["relation"]

    query = f"""
    MATCH (s {{id: $source}}), (t {{id: $target}})
    MERGE (s)-[:{relation}]->(t)
    RETURN type(r) AS relation;
    """

    print(query)
# Out:
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
