# %%
from neo4j import GraphDatabase
 
# Define correct URI and AUTH arguments (no AUTH by default)
URI = "bolt://localhost:7687"
AUTH = ("", "")
 
with GraphDatabase.driver(URI, auth=AUTH) as client:
    # Check the connection
    client.verify_connectivity()
 
    # Find a user John in the database
    records, summary, keys = client.execute_query(
        "CALL export_util.json('/usr/lib/memgraph/query_modules/export.json') YIELD objects return objects;",
        database_="memgraph",
    )
 
    # Get the result
    for record in records:
        print(record["name"])
 
    # Print the query
    print(summary.query)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[1], line 12
#       9 client.verify_connectivity()
#      11 # Find a user John in the database
# ---> 12 records, summary, keys = client.execute_query(
#      13     "CALL export_util.json('/usr/lib/memgraph/query_modules/export.json') YIELD objects return objects;",
#      14     database_="memgraph",
#      15 )
#      17 # Get the result
#      18 for record in records:
#
# File c:\lopu-kg-test\project\.venv\Lib\site-packages\neo4j\_sync\driver.py:970, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     966     raise ValueError(
#     967         f"Invalid routing control value: {routing_!r}"
#     968     )
#     969 with session._pipelined_begin:
# --> 970     return session._run_transaction(
#     971         access_mode,
#     972         TelemetryAPI.DRIVER,
#     973         work,
#     974         (query_str, parameters, result_transformer_),
#     975         {},
#     976     )
#
# File c:\lopu-kg-test\project\.venv\Lib\site-packages\neo4j\_sync\work\session.py:583, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     581 tx = self._transaction
#     582 try:
# --> 583     result = transaction_function(tx, *args, **kwargs)
#     584 except asyncio.CancelledError:
#     585     # if cancellation callback has not been called yet:
#     586     if self._transaction is not None:
#
# File c:\lopu-kg-test\project\.venv\Lib\site-packages\neo4j\_sync\driver.py:1307, in _work(tx, query, parameters, transformer)
#    1300 def _work(
#    1301     tx: ManagedTransaction,
#    1302     query: te.LiteralString,
#    1303     parameters: dict[str, t.Any],
#    1304     transformer: t.Callable[[Result], t.Union[_T]],
#    1305 ) -> _T:
#    1306     res = tx.run(query, parameters)
# -> 1307     return transformer(res)
#
# File c:\lopu-kg-test\project\.venv\Lib\site-packages\neo4j\_sync\work\result.py:802, in Result.to_eager_result(self)
#     784 @NonConcurrentMethodChecker._non_concurrent_method
#     785 def to_eager_result(self) -> EagerResult:
#     786     """
#     787     Convert this result to an :class:`.EagerResult`.
#     788
#    (...)
#     800     .. versionchanged:: 5.8 Stabilized from experimental.
#     801     """
# --> 802     self._buffer_all()
#     803     return EagerResult(
#     804         keys=list(self.keys()),
#     805         records=Util.list(self),
#     806         summary=self.consume(),
#     807     )
#
# File c:\lopu-kg-test\project\.venv\Lib\site-packages\neo4j\_sync\work\result.py:459, in Result._buffer_all(self)
#     458 def _buffer_all(self):
# --> 459     self._buffer()
#
# File c:\lopu-kg-test\project\.venv\Lib\site-packages\neo4j\_sync\work\result.py:448, in Result._buffer(self, n)
#     446     return
#     447 record_buffer = deque()
# --> 448 for record in self:
#     449     record_buffer.append(record)
#     450     if n is not None and len(record_buffer) >= n:
#
# File c:\lopu-kg-test\project\.venv\Lib\site-packages\neo4j\_sync\work\result.py:398, in Result.__iter__(self)
#     396     yield self._record_buffer.popleft()
#     397 elif self._streaming:
# --> 398     self._connection.fetch_message()
#     399 elif self._discarding:
#     400     self._discard()
#
# File c:\lopu-kg-test\project\.venv\Lib\site-packages\neo4j\_sync\io\_common.py:184, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     182 def inner(*args, **kwargs):
#     183     try:
# --> 184         func(*args, **kwargs)
#     185     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     186         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File c:\lopu-kg-test\project\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_message(self)
#     860 # Receive exactly one message
#     861 tag, fields = self.inbox.pop(
#     862     hydration_hooks=self.responses[0].hydration_hooks
#     863 )
# --> 864 res = self._process_message(tag, fields)
#     865 self.idle_since = monotonic()
#     866 return res
#
# File c:\lopu-kg-test\project\.venv\Lib\site-packages\neo4j\_sync\io\_bolt5.py:500, in Bolt5x0._process_message(self, tag, fields)
#     498 self._server_state_manager.state = self.bolt_states.FAILED
#     499 try:
# --> 500     response.on_failure(summary_metadata or {})
#     501 except (ServiceUnavailable, DatabaseUnavailable):
#     502     if self.pool:
#
# File c:\lopu-kg-test\project\.venv\Lib\site-packages\neo4j\_sync\io\_common.py:254, in Response.on_failure(self, metadata)
#     252 handler = self.handlers.get("on_summary")
#     253 Util.callback(handler)
# --> 254 raise self._hydrate_error(metadata)
#
# ClientError: {code: Memgraph.ClientError.MemgraphError.MemgraphError} {message: export_util.json: Traceback (most recent call last):
#   File "/usr/lib/memgraph/query_modules/export_util.py", line 542, in json_dump_to_file
#     with open(path, "w") as outfile:
# PermissionError: [Errno 13] Permission denied: '/usr/lib/memgraph/query_modules/export.json'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/memgraph/query_modules/export_util.py", line 583, in json
#     json_dump_to_file(graph, path)
#   File "/usr/lib/memgraph/query_modules/export_util.py", line 550, in json_dump_to_file
#     raise PermissionError(
# PermissionError: You don't have permissions to write into that file. Make sure to give the necessary permissions to user memgraph.
# }

# %%
def restructure_json_list(data_list):
    """
    Restructures a list of JSON-like dictionaries to group relationships by the 'relationship' key.

    Args:
        data_list: A list of dictionaries, where each dictionary contains a 'relationship' key.

    Returns:
        A dictionary where the 'relationship' key maps to a list of relationship dictionaries.
    """
    if not isinstance(data_list, list):
      return data_list #raise TypeError("Input must be a list")

    nodes = []
    for item in data_list:
        if isinstance(item, dict) and 'node' in item and isinstance(item['node'], dict):
            node = item['node'].copy()  # Create a copy to avoid modifying the original
            if 'name' in node:
                node['id'] = node.pop('name')  # Rename 'name' to 'id'
            nodes.append(node)

    #return {"nodes": nodes}

    relationships = []
    for item in data_list:
        if isinstance(item, dict) and 'relationship' in item and isinstance(item['relationship'], dict):
            relationships.append(item['relationship'])
        #if you have other keys in the original list, you can add more elif statements here.

    return {"nodes": nodes,
        "relationships": relationships}

# %%
def transform_nodes(nodes_list):
    """
    Transforms a list of node dictionaries from the given format to {'id': '...', 'type': '...'}.

    Args:
        nodes_list: A list of node dictionaries.

    Returns:
        A list of transformed node dictionaries.
    """
    if not isinstance(nodes_list, list):
      raise TypeError("Input must be a list")

    transformed_nodes = []
    for node in nodes_list:
        if isinstance(node, dict) and 'id' in node and 'labels' in node and isinstance(node['labels'], list) and len(node['labels']) > 0:
            transformed_node = {'id': node['id'], 'type': node['labels'][0].replace(" ", "")} #remove spaces in the type name.
            transformed_nodes.append(transformed_node)
        #if you have other node formats, add elif statements here.
        else:
            transformed_nodes.append(node)
    return transformed_nodes

# %%
from neo4j import GraphDatabase
import json

# Define connection details
URI = "bolt://localhost:7687"
AUTH = ("", "")  # No authentication for Memgraph

# Load JSON data from a file
def load_json_from_file(filename):
    with open(filename, "r", encoding="utf-8") as file:
        print("Opening file: ", filename)
        return json.load(file)

# Function to load data into Memgraph
def load_graph_from_json(json_data):
    with GraphDatabase.driver(URI, auth=AUTH) as client:
        client.verify_connectivity()
        json_data = restructure_json_list(json_data)

        

        # Create Nodes
        for node in transform_nodes(json_data["nodes"]):
            query = """
            MERGE (n:$type {id: $id})
            RETURN n.id AS name;
            """
            
            records, _, _ = client.execute_query(query, type=node["type"], id=node["id"], database_="memgraph")

            # Print created nodes
            for record in records:
                print("Created node:", record["name"])

        # Create Relationships
        for rel in transform_nodes(json_data["relationships"]):
            source = rel["source"]
            target = rel["target"]
            relation = rel["relation"]

            query = f"""
            MATCH (s {{id: $source}}), (t {{id: $target}})
            MERGE (s)-[r:{relation}]->(t)
            RETURN type(r) AS relation;
            """
            
            print("Executing Query:", query)  # Debugging output
            
            records, _, _ = client.execute_query(
                query, source=source, target=target, database_="memgraph"
            )

            # Print created relationships
            for record in records:
                print("Created relationship:", record["relation"])

# Load JSON from file and insert it into Memgraph
#json_filename = "answer_from_LLM.json"  # Replace with your actual file path
#json_data = load_json_from_file(json_filename)
#load_graph_from_json(json_data)

# %%
# UUS 14.04

from neo4j import GraphDatabase
import json

# Define connection details
URI = "bolt://localhost:7687"
AUTH = ("", "")  # No authentication for Memgraph

# Load JSON data from a file
def load_json_from_file(filename):
    with open(filename, "r", encoding="utf-8") as file:
        print("Opening file: ", filename)
        return json.load(file)

def parse_identifier(identifier):
    """Parses 'schema.table.column' into (schema, table, column)."""
    parts = identifier.split('.')
    if len(parts) == 3:
        return parts[0], parts[1], parts[2]
    elif len(parts) == 2: # Handle case like 'schema.table' if needed, though column expected
         print(f"Warning: Identifier '{identifier}' only has 2 parts. Assuming table level.")
         return parts[0], parts[1], None
    else:
        raise ValueError(f"Invalid identifier format: {identifier}")


# Function to load data into Memgraph
def load_graph_from_json(json_data):
    with GraphDatabase.driver(URI, auth=AUTH) as client:
        client.verify_connectivity()

def load_lineage_to_memgraph(db, data):
    """Loads the lineage JSON data into Memgraph."""
    target_full_table_name = data['target_table']
    target_schema_name, target_table_name = target_full_table_name.split('.')




lineage_path = "C:\lopu-kg-test\project\src\LLM_answers\llm_prompt_for_column_level_lineage_hard_wo_ex\\answer_3_wh_db.DimCustomer_20250411_180418.json"  # -- NENDEGA PRAEGU EI TÖÖTA, sest on liiga detailsed
lineage_content = load_json_from_file(lineage_path)
# Out:
# Opening file:  C:\lopu-kg-test\project\src\LLM_answers\llm_prompt_for_column_level_lineage_hard_wo_ex\answer_3_wh_db.DimCustomer_20250411_180418.json

# %%
def transform_lineage_to_nodes_rels(data):
    """
    Transforms the original lineage JSON into separate lists of nodes
    and relationships suitable for the generic loading pattern.
    """
    nodes = {} # Use dict to ensure uniqueness by full_name
    relationships = []

    target_full_table_name = data['target_table']
    target_schema_name, target_table_name = target_full_table_name.split('.')

    # Add target schema, table
    nodes[target_schema_name] = {"id": target_schema_name, "label": "Schema", "props": {"name": target_schema_name}}
    nodes[target_full_table_name] = {"id": target_full_table_name, "label": "Table", "props": {"name": target_table_name, "full_name": target_full_table_name}}
    relationships.append({"source": target_full_table_name, "target": target_schema_name, "type": "BELONGS_TO", "props": {}})

    # Process each target column
    for target_col_name, lineage_info in data['lineage'].items():
        target_col_full_name = f"{target_full_table_name}.{target_col_name}"

        # Add target column node
        nodes[target_col_full_name] = {"id": target_col_full_name, "label": "Column", "props": {"name": target_col_name, "full_name": target_col_full_name}}
        relationships.append({"source": target_full_table_name, "target": target_col_full_name, "type": "HAS_COLUMN", "props": {}})

        # Process sources
        for source_info in lineage_info['sources']:
            try:
                source_identifier = source_info['source_identifier']
                src_schema_name, src_table_name, src_col_name = parse_identifier(source_identifier)
                src_full_table_name = f"{src_schema_name}.{src_table_name}"
                src_col_full_name = f"{src_full_table_name}.{src_col_name}"

                # Add source schema, table, column nodes (if not already added)
                if src_schema_name not in nodes:
                    nodes[src_schema_name] = {"id": src_schema_name, "label": "Schema", "props": {"name": src_schema_name}}
                if src_full_table_name not in nodes:
                    nodes[src_full_table_name] = {"id": src_full_table_name, "label": "Table", "props": {"name": src_table_name, "full_name": src_full_table_name}}
                    relationships.append({"source": src_full_table_name, "target": src_schema_name, "type": "BELONGS_TO", "props": {}})
                if src_col_full_name not in nodes:
                    nodes[src_col_full_name] = {"id": src_col_full_name, "label": "Column", "props": {"name": src_col_name, "full_name": src_col_full_name}}
                    relationships.append({"source": src_full_table_name, "target": src_col_full_name, "type": "HAS_COLUMN", "props": {}})

                # Prepare DERIVES relationship properties
                rel_props = {
                    "transformation_type": lineage_info.get("transformation_type"),
                    "transformation_logic": lineage_info.get("transformation_logic"),
                    "path": str(source_info.get("path")),
                    "role": source_info.get("role"),
                    "join_info": json.dumps(source_info.get("join_info")) if source_info.get("join_info") else None,
                    "notes": lineage_info.get("notes"),
                }
                rel_props = {k: v for k, v in rel_props.items() if v is not None} # Clean None values

                # Add DERIVES relationship
                relationships.append({
                    "source": src_col_full_name,
                    "target": target_col_full_name,
                    "type": "DERIVES",
                    "props": rel_props
                })

            except ValueError as e:
                print(f"    Skipping source due to error: {e}")
            except Exception as e:
                 print(f"    An unexpected error occurred processing source {source_info.get('source_identifier', 'UNKNOWN')}: {e}")

    return {"nodes": list(nodes.values()), "relationships": relationships}

transform_lineage_to_nodes_rels(lineage_content)
# Out:
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
#     An unexpected error occurred processing source UNKNOWN: 'source_identifier'
# {'nodes': [{'id': 'wh_db', 'label': 'Schema', 'props': {'name': 'wh_db'}},
#   {'id': 'wh_db.DimCustomer',
#    'label': 'Table',
#    'props': {'name': 'DimCustomer', 'full_name': 'wh_db.DimCustomer'}},
#   {'id': 'wh_db.DimCustomer.sk_customerid',
#    'label': 'Column',
#    'props': {'name': 'sk_customerid',
#     'full_name': 'wh_db.DimCustomer.sk_customerid'}},
#   {'id': 'wh_db.DimCustomer.customerid',
#    'label': 'Column',
#    'props': {'name': 'customerid',
#     'full_name': 'wh_db.DimCustomer.customerid'}},
#   {'id': 'wh_db.DimCustomer.taxid',
#    'label': 'Column',
#    'props': {'name': 'taxid', 'full_name': 'wh_db.DimCustomer.taxid'}},
#   {'id': 'wh_db.DimCustomer.status',
#    'label': 'Column',
#    'props': {'name': 'status', 'full_name': 'wh_db.DimCustomer.status'}},
#   {'id': 'wh_db.DimCustomer.lastname',
#    'label': 'Column',
#    'props': {'name': 'lastname', 'full_name': 'wh_db.DimCustomer.lastname'}},
#   {'id': 'wh_db.DimCustomer.firstname',
#    'label': 'Column',
#    'props': {'name': 'firstname', 'full_name': 'wh_db.DimCustomer.firstname'}},
#   {'id': 'wh_db.DimCustomer.middleinitial',
#    'label': 'Column',
#    'props': {'name': 'middleinitial',
#     'full_name': 'wh_db.DimCustomer.middleinitial'}},
#   {'id': 'wh_db.DimCustomer.gender',
#    'label': 'Column',
#    'props': {'name': 'gender', 'full_name': 'wh_db.DimCustomer.gender'}},
#   {'id': 'wh_db.DimCustomer.tier',
#    'label': 'Column',
#    'props': {'name': 'tier', 'full_name': 'wh_db.DimCustomer.tier'}},
#   {'id': 'wh_db.DimCustomer.dob',
#    'label': 'Column',
#    'props': {'name': 'dob', 'full_name': 'wh_db.DimCustomer.dob'}},
#   {'id': 'wh_db.DimCustomer.addressline1',
#    'label': 'Column',
#    'props': {'name': 'addressline1',
#     'full_name': 'wh_db.DimCustomer.addressline1'}},
#   {'id': 'wh_db.DimCustomer.addressline2',
#    'label': 'Column',
#    'props': {'name': 'addressline2',
#     'full_name': 'wh_db.DimCustomer.addressline2'}},
#   {'id': 'wh_db.DimCustomer.postalcode',
#    'label': 'Column',
#    'props': {'name': 'postalcode',
#     'full_name': 'wh_db.DimCustomer.postalcode'}},
#   {'id': 'wh_db.DimCustomer.city',
#    'label': 'Column',
#    'props': {'name': 'city', 'full_name': 'wh_db.DimCustomer.city'}},
#   {'id': 'wh_db.DimCustomer.stateprov',
#    'label': 'Column',
#    'props': {'name': 'stateprov', 'full_name': 'wh_db.DimCustomer.stateprov'}},
#   {'id': 'wh_db.DimCustomer.country',
#    'label': 'Column',
#    'props': {'name': 'country', 'full_name': 'wh_db.DimCustomer.country'}},
#   {'id': 'wh_db.DimCustomer.phone1',
#    'label': 'Column',
#    'props': {'name': 'phone1', 'full_name': 'wh_db.DimCustomer.phone1'}},
#   {'id': 'wh_db.DimCustomer.phone2',
#    'label': 'Column',
#    'props': {'name': 'phone2', 'full_name': 'wh_db.DimCustomer.phone2'}},
#   {'id': 'wh_db.DimCustomer.phone3',
#    'label': 'Column',
#    'props': {'name': 'phone3', 'full_name': 'wh_db.DimCustomer.phone3'}},
#   {'id': 'wh_db.DimCustomer.email1',
#    'label': 'Column',
#    'props': {'name': 'email1', 'full_name': 'wh_db.DimCustomer.email1'}},
#   {'id': 'wh_db.DimCustomer.email2',
#    'label': 'Column',
#    'props': {'name': 'email2', 'full_name': 'wh_db.DimCustomer.email2'}},
#   {'id': 'wh_db.DimCustomer.nationaltaxratedesc',
#    'label': 'Column',
#    'props': {'name': 'nationaltaxratedesc',
#     'full_name': 'wh_db.DimCustomer.nationaltaxratedesc'}},
#   {'id': 'wh_db.DimCustomer.nationaltaxrate',
#    'label': 'Column',
#    'props': {'name': 'nationaltaxrate',
#     'full_name': 'wh_db.DimCustomer.nationaltaxrate'}},
#   {'id': 'wh_db.DimCustomer.localtaxratedesc',
#    'label': 'Column',
#    'props': {'name': 'localtaxratedesc',
#     'full_name': 'wh_db.DimCustomer.localtaxratedesc'}},
#   {'id': 'wh_db.DimCustomer.localtaxrate',
#    'label': 'Column',
#    'props': {'name': 'localtaxrate',
#     'full_name': 'wh_db.DimCustomer.localtaxrate'}},
#   {'id': 'wh_db.DimCustomer.agencyid',
#    'label': 'Column',
#    'props': {'name': 'agencyid', 'full_name': 'wh_db.DimCustomer.agencyid'}},
#   {'id': 'wh_db.DimCustomer.creditrating',
#    'label': 'Column',
#    'props': {'name': 'creditrating',
#     'full_name': 'wh_db.DimCustomer.creditrating'}},
#   {'id': 'wh_db.DimCustomer.networth',
#    'label': 'Column',
#    'props': {'name': 'networth', 'full_name': 'wh_db.DimCustomer.networth'}},
#   {'id': 'wh_db.DimCustomer.marketingnameplate',
#    'label': 'Column',
#    'props': {'name': 'marketingnameplate',
#     'full_name': 'wh_db.DimCustomer.marketingnameplate'}},
#   {'id': 'wh_db.DimCustomer.iscurrent',
#    'label': 'Column',
#    'props': {'name': 'iscurrent', 'full_name': 'wh_db.DimCustomer.iscurrent'}},
#   {'id': 'wh_db.DimCustomer.batchid',
#    'label': 'Column',
#    'props': {'name': 'batchid', 'full_name': 'wh_db.DimCustomer.batchid'}},
#   {'id': 'wh_db.DimCustomer.effectivedate',
#    'label': 'Column',
#    'props': {'name': 'effectivedate',
#     'full_name': 'wh_db.DimCustomer.effectivedate'}},
#   {'id': 'wh_db.DimCustomer.enddate',
#    'label': 'Column',
#    'props': {'name': 'enddate', 'full_name': 'wh_db.DimCustomer.enddate'}}],
#  'relationships': [{'source': 'wh_db.DimCustomer',
#    'target': 'wh_db',
#    'type': 'BELONGS_TO',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.sk_customerid',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.customerid',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.taxid',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.status',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.lastname',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.firstname',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.middleinitial',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.gender',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.tier',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.dob',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.addressline1',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.addressline2',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.postalcode',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.city',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.stateprov',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.country',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.phone1',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.phone2',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.phone3',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.email1',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.email2',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.nationaltaxratedesc',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.nationaltaxrate',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.localtaxratedesc',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.localtaxrate',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.agencyid',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.creditrating',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.networth',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.marketingnameplate',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.iscurrent',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.batchid',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.effectivedate',
#    'type': 'HAS_COLUMN',
#    'props': {}},
#   {'source': 'wh_db.DimCustomer',
#    'target': 'wh_db.DimCustomer.enddate',
#    'type': 'HAS_COLUMN',
#    'props': {}}]}

# %%
import json
from neo4j import GraphDatabase, basic_auth # Import Neo4j driver components

# --- Configuration ---
# NOTE: Use 'neo4j://...' or 'bolt://...' for the URI with the neo4j driver
# Memgraph typically runs Bolt on 7687
URI = "bolt://localhost:7687"
# If using Memgraph Cloud / AuraDB or Memgraph with authentication enabled:
# AUTH = basic_auth("your_user", "your_password")
AUTH = None # Set to None or remove if no authentication

# Your lineage data (same as before)
lineage_data = {
  "target_table": "wh.DimComp",
  # ... (rest of your lineage_data JSON) ...
  "lineage": {
    "sk_compid": {
      "sources": [
        {"source_identifier": "wh_stg.FW.value", "path": ["cmp.RecDate", "T.effectivedate"], "role": "Date part source"},
        {"source_identifier": "wh_stg.FW.value", "path": ["cmp.CIK", "T.compid"], "role": "ID part source"}
      ],
      "transformation_type": "EXPRESSION_CONCAT",
      "transformation_logic": "CAST(strftime(T.effectivedate, '%Y%m%d') || T.compid AS BIGINT)"
    },
    "compid": {
      "sources": [{"source_identifier": "wh_stg.FW.value", "path": ["cmp.CIK"]}],
      "transformation_type": "CAST",
      "transformation_logic": "CAST(cmp.CIK AS BIGINT)"
    },
    "status": {
      "sources": [{"source_identifier": "wh_stg.FW.value", "path": ["cmp.Status"]}],
      "transformation_type": "CASE_MAPPING",
      "transformation_logic": "CASE cmp.Status WHEN 'ACTV' THEN 'Active' ELSE 'Inactive' END"
    },
    "name": {
      "sources": [{"source_identifier": "wh_stg.FW.value", "path": ["cmp.CompName"]}],
      "transformation_type": "RENAME",
      "transformation_logic": "cmp.CompName AS name"
    },
    "industry": {
      "sources": [
          {"source_identifier": "wh.Ind.in_name",
           "join_info": {
             "type": "INNER JOIN",
             "left_source": {"identifier": "wh_stg.FW.value", "path": ["cmp.IndID"]},
             "right_source": {"identifier": "wh.Ind.in_id"}
           }
          }
      ],
      "transformation_type": "JOIN_LOOKUP",
      "transformation_logic": "ind.in_name via JOIN ON cmp.IndID = ind.in_id"
    },
    "effectivedate": {
        "sources": [{"source_identifier": "wh_stg.FW.value", "path": ["cmp.RecDate"]}],
        "transformation_type": "RENAME",
        "transformation_logic": "cmp.RecDate AS effectivedate"
    },
    "enddate": {
      "sources": [
        {"source_identifier": "wh_stg.FW.value", "path": ["cmp.RecDate"], "role": "Input for LEAD"},
        {"source_identifier": "wh_stg.FW.value", "path": ["cmp.CIK"], "role": "Partition key for LEAD"}
      ],
      "transformation_type": "WINDOW_FUNCTION",
      "transformation_logic": "COALESCE(LEAD(cmp.RecDate) OVER (PARTITION BY cmp.CIK ORDER BY cmp.RecDate), '9999-12-31'::DATE)",
      "notes": "SCD2 end date calculation"
    }
  }
}


# --- Helper Function ---
def parse_identifier(identifier):
    parts = identifier.split('.')
    if len(parts) == 3:
        return parts[0], parts[1], parts[2]
    elif len(parts) == 2:
         print(f"Warning: Identifier '{identifier}' only has 2 parts. Assuming table level.")
         return parts[0], parts[1], None
    else:
        raise ValueError(f"Invalid identifier format: {identifier}")

# --- Data Transformation Step (Required for the neo4j driver template) ---
def transform_lineage_to_nodes_rels(data):
    """
    Transforms the original lineage JSON into separate lists of nodes
    and relationships suitable for the generic loading pattern.
    """
    nodes = {} # Use dict to ensure uniqueness by full_name
    relationships = []

    target_full_table_name = data['target_table']
    target_schema_name, target_table_name = target_full_table_name.split('.')

    # Add target schema, table
    nodes[target_schema_name] = {"id": target_schema_name, "label": "Schema", "props": {"name": target_schema_name}}
    nodes[target_full_table_name] = {"id": target_full_table_name, "label": "Table", "props": {"name": target_table_name, "full_name": target_full_table_name}}
    relationships.append({"source": target_full_table_name, "target": target_schema_name, "type": "BELONGS_TO", "props": {}})

    # Process each target column
    for target_col_name, lineage_info in data['lineage'].items():
        target_col_full_name = f"{target_full_table_name}.{target_col_name}"

        # Add target column node
        nodes[target_col_full_name] = {"id": target_col_full_name, "label": "Column", "props": {"name": target_col_name, "full_name": target_col_full_name}}
        relationships.append({"source": target_full_table_name, "target": target_col_full_name, "type": "HAS_COLUMN", "props": {}})

        # Process sources
        for source_info in lineage_info['sources']:
            try:
                source_identifier = source_info['source_identifier']
                src_schema_name, src_table_name, src_col_name = parse_identifier(source_identifier)
                src_full_table_name = f"{src_schema_name}.{src_table_name}"
                src_col_full_name = f"{src_full_table_name}.{src_col_name}"

                # Add source schema, table, column nodes (if not already added)
                if src_schema_name not in nodes:
                    nodes[src_schema_name] = {"id": src_schema_name, "label": "Schema", "props": {"name": src_schema_name}}
                if src_full_table_name not in nodes:
                    nodes[src_full_table_name] = {"id": src_full_table_name, "label": "Table", "props": {"name": src_table_name, "full_name": src_full_table_name}}
                    relationships.append({"source": src_full_table_name, "target": src_schema_name, "type": "BELONGS_TO", "props": {}})
                if src_col_full_name not in nodes:
                    nodes[src_col_full_name] = {"id": src_col_full_name, "label": "Column", "props": {"name": src_col_name, "full_name": src_col_full_name}}
                    relationships.append({"source": src_full_table_name, "target": src_col_full_name, "type": "HAS_COLUMN", "props": {}})

                # Prepare DERIVES relationship properties
                rel_props = {
                    "transformation_type": lineage_info.get("transformation_type"),
                    "transformation_logic": lineage_info.get("transformation_logic"),
                    "path": str(source_info.get("path")),
                    "role": source_info.get("role"),
                    "join_info": json.dumps(source_info.get("join_info")) if source_info.get("join_info") else None,
                    "notes": lineage_info.get("notes"),
                }
                rel_props = {k: v for k, v in rel_props.items() if v is not None} # Clean None values

                # Add DERIVES relationship
                relationships.append({
                    "source": src_col_full_name,
                    "target": target_col_full_name,
                    "type": "DERIVES",
                    "props": rel_props
                })

            except ValueError as e:
                print(f"    Skipping source due to error: {e}")
            except Exception as e:
                 print(f"    An unexpected error occurred processing source {source_info.get('source_identifier', 'UNKNOWN')}: {e}")

    return {"nodes": list(nodes.values()), "relationships": relationships}

# --- Main Loading Logic using neo4j driver ---
def load_graph_with_neo4j_driver(data_for_graph):
    """Loads nodes and relationships using the neo4j driver."""
    # Note: Specifying database_="memgraph" might not be necessary unless
    # your Memgraph instance explicitly requires multi-database support AND
    # the driver/Memgraph version supports it via Bolt. Often, you connect
    # directly to the target database implicitly. Remove if it causes issues.
    database_name = "memgraph" # Or None if not needed/supported

    with GraphDatabase.driver(URI, auth=AUTH) as driver:
        driver.verify_connectivity()
        print("Connected to Memgraph using neo4j driver.")

        # Optional: Create constraints/indexes (run once or ensure idempotency)
        try:
            constraints_indexes = [
                "CREATE CONSTRAINT IF NOT EXISTS FOR (s:Schema) REQUIRE s.name IS UNIQUE;",
                "CREATE INDEX IF NOT EXISTS FOR (s:Schema) ON (s.name);",
                "CREATE CONSTRAINT IF NOT EXISTS FOR (t:Table) REQUIRE t.full_name IS UNIQUE;",
                "CREATE INDEX IF NOT EXISTS FOR (t:Table) ON (t.full_name);",
                "CREATE CONSTRAINT IF NOT EXISTS FOR (c:Column) REQUIRE c.full_name IS UNIQUE;",
                "CREATE INDEX IF NOT EXISTS FOR (c:Column) ON (c.full_name);",
            ]
            for query in constraints_indexes:
                 # Use session for auto-commit or explicit transaction
                 driver.execute_query(query, database_=database_name)
            print("Ensured necessary constraints and indexes exist.")
        except Exception as e:
            print(f"Warning: Could not ensure constraints/indexes (might exist already): {e}")


        # Create/Merge Nodes
        print("\n--- Merging Nodes ---")
        for node_data in data_for_graph["nodes"]:
            # Use explicit labels and the correct identifier (full_name or name)
            # MERGE based on the unique identifier property
            identifier_key = "full_name" if node_data["label"] in ["Table", "Column"] else "name"
            identifier_value = node_data["props"][identifier_key]

            query = f"""
            MERGE (n:{node_data['label']} {{{identifier_key}: $id_val}})
            ON CREATE SET n = $props
            ON MATCH SET n += $props // Update properties if node exists
            RETURN n.{identifier_key} AS id
            """
            try:
                summary = driver.execute_query(
                    query,
                    id_val=identifier_value,
                    props=node_data["props"],
                    database_=database_name
                )
                # Access results correctly if needed (summary often just confirms execution)
                # print(f"  Merged node: {node_data['label']} {identifier_value}")
            except Exception as e:
                print(f"  Error merging node {node_data['label']} {identifier_value}: {e}")
                print(f"    Query: {query}")
                print(f"    Params: id_val={identifier_value}, props={node_data['props']}")


        # Create/Merge Relationships
        print("\n--- Merging Relationships ---")
        for rel_data in data_for_graph["relationships"]:
            source_id = rel_data["source"]
            target_id = rel_data["target"]
            rel_type = rel_data["type"]
            rel_props = rel_data["props"]

            # Determine match keys for source/target nodes
            # This assumes nodes were created/merged using specific unique keys
            # We need to know the *label* to know which key to match on! This is awkward.
            # Finding the label requires looking back at the node list or a more complex query.
            # --> Sticking to full_name/name as the assumed key for MERGE is simpler here.
            # --> This highlights a weakness of the generic node/rel structure compared to specific queries.

            # Simplified: Assume Table/Column use full_name, Schema uses name.
            # A better implementation might pass the label info along.
            source_key = "full_name" if "." in source_id else "name"
            target_key = "full_name" if "." in target_id else "name"


            # Use parameters for properties, but f-string/concatenation for relationship type
            query = f"""
            MATCH (s {{{source_key}: $source_val}})
            MATCH (t {{{target_key}: $target_val}})
            MERGE (s)-[r:{rel_type}]->(t)
            ON CREATE SET r = $props
            ON MATCH SET r += $props // Update properties
            RETURN type(r) AS type
            """
            try:
                summary = driver.execute_query(
                    query,
                    source_val=source_id,
                    target_val=target_id,
                    props=rel_props,
                    database_=database_name
                )
                # print(f"  Merged relationship: ({source_id})-[{rel_type}]->({target_id})")
            except Exception as e:
                 print(f"  Error merging relationship ({source_id})-[{rel_type}]->({target_id}): {e}")
                 print(f"    Query: {query}")
                 print(f"    Params: source_val={source_id}, target_val={target_id}, props={rel_props}")


# --- Run the process ---
try:
    # 1. Transform the original data
    print("Transforming lineage data...")
    graph_data = transform_lineage_to_nodes_rels(lineage_data)
    # print("\nTransformed Data:")
    # print(json.dumps(graph_data, indent=2)) # Optional: view transformed data

    # 2. Load the transformed data using neo4j driver
    load_graph_with_neo4j_driver(graph_data)

    print("\nLineage loading process complete using neo4j driver.")

except Exception as e:
    print(f"\nAn overall error occurred: {e}")

# %%
import os

llm_answers_path = r"LLM_answers"
json_files = [f for f in os.listdir(llm_answers_path) if f.endswith(".json")]


for filename in json_files:
    llm_json_path = os.path.join(llm_answers_path, filename)
    json_data = load_json_from_file(llm_json_path)
    load_graph_from_json(json_data)
# Out:
# Opening file:  LLM_answers\answer_20250305_022711.json
# Created node: ProspectIncremental
# Created node: wh_db_stage
# Created node: agencyid
# Created node: lastname
# Created node: firstname
# Created node: middleinitial
# Created node: gender
# Created node: addressline1
# Created node: addressline2
# Created node: postalcode
# Created node: city
# Created node: state
# Created node: country
# Created node: phone
# Created node: income
# Created node: numbercars
# Created node: numberchildren
# Created node: maritalstatus
# Created node: age
# Created node: creditrating
# Created node: ownorrentflag
# Created node: employer
# Created node: numbercreditcards
# Created node: networth
# Created node: marketingnameplate
# Created node: recordbatchid
# Created node: Unique identifier from agency
# Created node: Last name
# Created node: First name
# Created node: Middle initial
# Created node: â€˜Mâ€™ or â€˜Fâ€™ or â€˜Uâ€™
# Created node: Postal address
# Created node: Postal address
# Created node: Postal code
# Created node: City
# Created node: State or province
# Created node: Postal country
# Created node: Telephone number
# Created node: Annual income
# Created node: Cars owned
# Created node: Dependent children
# Created node: â€˜Sâ€™ or â€˜Mâ€™ or â€˜Dâ€™ or â€˜Wâ€™ or â€˜Uâ€™
# Created node: Current age
# Created node: Numeric rating
# Created node: â€˜Oâ€™ or â€˜Râ€™ or â€˜Uâ€™
# Created node: Name of employer
# Created node: Credit cards
# Created node: Estimated total net worth
# Created node: Marketing nameplate
# Created node: Batch ID when this record last inserted
# Created node: ProspectIncremental table contains prospect data.
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Opening file:  LLM_answers\answer_20250305_022715.json
# Created node: batchdate
# Created node: BatchDate
# Created node: DATE
# Created node: wh_db
# Created node: Batch date
# Created node: batchid
# Created node: INT
# Created node: Batch ID when this record was inserted
# Created node: Contains batch processing dates and IDs.
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Opening file:  LLM_answers\answer_20250305_022724.json
# Created node: wh_db.DimAccount
# Created node: wh_db
# Created node: sk_accountid
# Created node: accountid
# Created node: sk_brokerid
# Created node: sk_customerid
# Created node: accountdesc
# Created node: taxstatus
# Created node: status
# Created node: iscurrent
# Created node: batchid
# Created node: effectivedate
# Created node: enddate
# Created node: BIGINT
# Created node: STRING
# Created node: TINYINT
# Created node: BOOLEAN
# Created node: INT
# Created node: DATE
# Created node: Surrogate key for AccountID
# Created node: Customer account identifier
# Created node: Surrogate key of managing broker
# Created node: Surrogate key of customer
# Created node: Name of customer account
# Created node: Tax status of this account
# Created node: Account status, active or closed
# Created node: True if this is the current record
# Created node: Batch ID when this record was inserted
# Created node: Beginning of date range when this record was the current record
# Created node: Ending of date range when this record was the current record. A record that is not expired will use the date 9999-12-31.
# Created node: Dimension table containing account information
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Opening file:  LLM_answers\answer_20250305_022736.json
# Created node: sk_brokerid
# Created node: DimBroker
# Created node: BIGINT
# Created node: wh_db
# Created node: brokerid
# Created node: BIGINT
# Created node: managerid
# Created node: BIGINT
# Created node: firstname
# Created node: STRING
# Created node: lastname
# Created node: STRING
# Created node: middleinitial
# Created node: STRING
# Created node: branch
# Created node: STRING
# Created node: office
# Created node: STRING
# Created node: phone
# Created node: STRING
# Created node: iscurrent
# Created node: BOOLEAN
# Created node: batchid
# Created node: INT
# Created node: effectivedate
# Created node: DATE
# Created node: enddate
# Created node: DATE
# Created node: Surrogate key for broker
# Created node: Natural key for broker
# Created node: Natural key for managerâ€™s HR record
# Created node: First name
# Created node: Last Name
# Created node: Middle initial
# Created node: Facility in which employee has office
# Created node: Office number or description
# Created node: Employee phone number
# Created node: True if this is the current record
# Created node: Batch ID when this record was inserted
# Created node: Beginning of date range when this record was the current record
# Created node: Ending of date range when this record was the current record. A record that is not expired will use the date 9999-12-31.
# Created node: Stores information about brokers
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Opening file:  LLM_answers\answer_20250305_022750.json
# Created node: sk_companyid
# Created node: DimCompany
# Created node: BIGINT
# Created node: wh_db
# Created node: Surrogate key for CompanyID
# Created node: companyid
# Created node: Company identifier (CIK number)
# Created node: status
# Created node: STRING
# Created node: Company status
# Created node: name
# Created node: Company name
# Created node: industry
# Created node: Companyâ€™s industry
# Created node: sprating
# Created node: Standard & Poor companyâ€™s rating
# Created node: islowgrade
# Created node: BOOLEAN
# Created node: True if this company is low grade
# Created node: ceo
# Created node: CEO name
# Created node: addressline1
# Created node: Address Line 1
# Created node: addressline2
# Created node: Address Line 2
# Created node: postalcode
# Created node: Zip or postal code
# Created node: city
# Created node: City
# Created node: stateprov
# Created node: State or Province
# Created node: country
# Created node: Country
# Created node: description
# Created node: Company description
# Created node: foundingdate
# Created node: DATE
# Created node: Date the company was founded
# Created node: iscurrent
# Created node: True if this is the current record
# Created node: batchid
# Created node: INT
# Created node: Batch ID when this record was inserted
# Created node: effectivedate
# Created node: Beginning of date range when this record was the current record
# Created node: enddate
# Created node: Ending of date range when this record was the current record. A record that is not expired will use the date 9999-12-31.
# Created node: Dimension table containing company information
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Opening file:  LLM_answers\answer_20250305_022811.json
# Opening file:  LLM_answers\answer_20250305_022828.json
# Created node: sk_dateid
# Created node: DimDate
# Created node: BIGINT
# Created node: wh_db
# Created node: Surrogate key for the date
# Created node: datevalue
# Created node: DATE
# Created node: The date stored appropriately for doing comparisons in the Data Warehouse
# Created node: datedesc
# Created node: STRING
# Created node: The date in full written form e.g. July 7 2004
# Created node: calendaryearid
# Created node: INT
# Created node: Year number as a number
# Created node: calendaryeardesc
# Created node: STRING
# Created node: Year number as text
# Created node: calendarqtrid
# Created node: INT
# Created node: Quarter as a number e.g. 20042
# Created node: calendarqtrdesc
# Created node: STRING
# Created node: Quarter as text e.g. 2004 Q2
# Created node: calendarmonthid
# Created node: INT
# Created node: Month as a number e.g. 20047
# Created node: calendarmonthdesc
# Created node: STRING
# Created node: Month as text e.g. 2004 July
# Created node: calendarweekid
# Created node: INT
# Created node: Week as a number e.g. 200428
# Created node: calendarweekdesc
# Created node: STRING
# Created node: Week as text e.g. 2004-W28
# Created node: dayofweeknum
# Created node: INT
# Created node: Day of week as a number e.g. 3
# Created node: dayofweekdesc
# Created node: STRING
# Created node: Day of week as text e.g. Wednesday
# Created node: fiscalyearid
# Created node: INT
# Created node: Fiscal year as a number e.g. 2005
# Created node: fiscalyeardesc
# Created node: STRING
# Created node: Fiscal year as text e.g. 2005
# Created node: fiscalqtrid
# Created node: INT
# Created node: Fiscal quarter as a number e.g. 20051
# Created node: fiscalqtrdesc
# Created node: STRING
# Created node: Fiscal quarter as text e.g. 2005 Q1
# Created node: holidayflag
# Created node: BOOLEAN
# Created node: Indicates holidays
# Created node: Stores date dimension information
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
# ...
# Created node: numbercars
# Created node: INT
# Created node: Cars owned
# Created node: numberchildren
# Created node: Dependent children
# Created node: maritalstatus
# Created node: â€˜Sâ€™ or â€˜Mâ€™ or â€˜Dâ€™ or â€˜Wâ€™ or â€˜Uâ€™
# Created node: age
# Created node: Current age
# Created node: creditrating
# Created node: Numeric rating
# Created node: ownorrentflag
# Created node: â€˜Oâ€™ or â€˜Râ€™ or â€˜Uâ€™
# Created node: employer
# Created node: Name of employer
# Created node: numbercreditcards
# Created node: Credit cards
# Created node: networth
# Created node: Estimated total net worth
# Created node: marketingnameplate
# Created node: Marketing nameplate
# Created node: recordbatchid
# Created node: Batch ID when this record last inserted
# Created node: Table containing incremental prospect data
# Created node: Postal address
# Created node: batchid
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:DESCRIBES]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: DESCRIBES
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:PART_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: PART_OF
# Executing Query:
#             MATCH (s {id: $source}), (t {id: $target})
#             MERGE (s)-[r:TYPE_OF]->(t)
#             RETURN type(r) AS relation;
#
# Created relationship: TYPE_OF
# Created relationship: TYPE_OF

# %%
asd = load_json_from_file(r"LLM_answers\answer_20250305_022936.json")
asd2 = load_json_from_file(r"LLM_answers\answer_20250305_022947.json")
# Out:
# Opening file:  LLM_answers\answer_20250305_022936.json
# Opening file:  LLM_answers\answer_20250305_022947.json

# %%
asd["nodes"]
# Out:
# [{'id': 'wh_db.FactWatches',
#   'labels': ['TableName'],
#   'properties': {'name': 'wh_db.FactWatches'}},
#  {'id': 'sk_customerid',
#   'labels': ['ColumnName'],
#   'properties': {'name': 'sk_customerid'}},
#  {'id': 'sk_securityid',
#   'labels': ['ColumnName'],
#   'properties': {'name': 'sk_securityid'}},
#  {'id': 'sk_dateid_dateplaced',
#   'labels': ['ColumnName'],
#   'properties': {'name': 'sk_dateid_dateplaced'}},
#  {'id': 'sk_dateid_dateremoved',
#   'labels': ['ColumnName'],
#   'properties': {'name': 'sk_dateid_dateremoved'}},
#  {'id': 'batchid',
#   'labels': ['ColumnName'],
#   'properties': {'name': 'batchid'}},
#  {'id': 'BIGINT', 'labels': ['Data Type'], 'properties': {'name': 'BIGINT'}},
#  {'id': 'INT', 'labels': ['Data Type'], 'properties': {'name': 'INT'}},
#  {'id': 'wh_db', 'labels': ['SchemaName'], 'properties': {'name': 'wh_db'}},
#  {'id': 'Customer associated with watch list',
#   'labels': ['Comment'],
#   'properties': {'text': 'Customer associated with watch list'}},
#  {'id': 'Security listed on watch list',
#   'labels': ['Comment'],
#   'properties': {'text': 'Security listed on watch list'}},
#  {'id': 'Date the watch list item was added',
#   'labels': ['Comment'],
#   'properties': {'text': 'Date the watch list item was added'}},
#  {'id': 'Date the watch list item was removed',
#   'labels': ['Comment'],
#   'properties': {'text': 'Date the watch list item was removed'}},
#  {'id': 'Batch ID when this record was inserted',
#   'labels': ['Comment'],
#   'properties': {'text': 'Batch ID when this record was inserted'}},
#  {'id': 'FactWatches stores watch list information',
#   'labels': ['Summary'],
#   'properties': {'text': 'FactWatches stores watch list information'}}]

# %%
def transform_nodes(nodes_list):
    """
    Transforms a list of node dictionaries from the given format to {'id': '...', 'type': '...'}.

    Args:
        nodes_list: A list of node dictionaries.

    Returns:
        A list of transformed node dictionaries.
    """
    if not isinstance(nodes_list, list):
      raise TypeError("Input must be a list")

    transformed_nodes = []
    for node in nodes_list:
        if isinstance(node, dict) and 'id' in node and 'labels' in node and isinstance(node['labels'], list) and len(node['labels']) > 0:
            transformed_node = {'id': node['id'], 'type': node['labels'][0].replace(" ", "")} #remove spaces in the type name.
            transformed_nodes.append(transformed_node)
        #if you have other node formats, add elif statements here.
        else:
            transformed_nodes.append(node)
    return transformed_nodes

# %%
transform_nodes(asd2["nodes"])
# Out:
# [{'id': 'sk_companyid', 'type': 'ColumnName'},
#  {'id': 'Financial', 'type': 'TableName'},
#  {'id': 'BIGINT', 'type': 'Data Type'},
#  {'id': 'wh_db', 'type': 'SchemaName'},
#  {'id': 'Company SK.', 'type': 'Comment'},
#  {'id': 'fi_year', 'type': 'ColumnName'},
#  {'id': 'INT', 'type': 'Data Type'},
#  {'id': 'Year of the quarter end.', 'type': 'Comment'},
#  {'id': 'fi_qtr', 'type': 'ColumnName'},
#  {'id': 'Quarter number that the financial information is for: valid values 1, 2, 3, 4.',
#   'type': 'Comment'},
#  {'id': 'fi_qtr_start_date', 'type': 'ColumnName'},
#  {'id': 'DATE', 'type': 'Data Type'},
#  {'id': 'Start date of quarter.', 'type': 'Comment'},
#  {'id': 'fi_revenue', 'type': 'ColumnName'},
#  {'id': 'DOUBLE', 'type': 'Data Type'},
#  {'id': 'Reported revenue for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_net_earn', 'type': 'ColumnName'},
#  {'id': 'Net earnings reported for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_basic_eps', 'type': 'ColumnName'},
#  {'id': 'Basic earnings per share for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_dilut_eps', 'type': 'ColumnName'},
#  {'id': 'Diluted earnings per share for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_margin', 'type': 'ColumnName'},
#  {'id': 'Profit divided by revenues for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_inventory', 'type': 'ColumnName'},
#  {'id': 'Value of inventory on hand at the end of quarter.',
#   'type': 'Comment'},
#  {'id': 'fi_assets', 'type': 'ColumnName'},
#  {'id': 'Value of total assets at the end of the quarter.', 'type': 'Comment'},
#  {'id': 'fi_liability', 'type': 'ColumnName'},
#  {'id': 'Value of total liabilities at the end of the quarter.',
#   'type': 'Comment'},
#  {'id': 'fi_out_basic', 'type': 'ColumnName'},
#  {'id': 'Average number of shares outstanding (basic).', 'type': 'Comment'},
#  {'id': 'fi_out_dilut', 'type': 'ColumnName'},
#  {'id': 'Average number of shares outstanding (diluted).', 'type': 'Comment'},
#  {'id': 'Financial data for companies', 'type': 'Summary'}]

# %%
def restructure_and_rename_nodes(data_list):
    """
    Restructures a list of JSON-like dictionaries to group nodes by the 'node' key,
    renames 'name' to 'id', and returns a dictionary with 'nodes' as the key.

    Args:
        data_list: A list of dictionaries, where each dictionary contains a 'node' key.

    Returns:
        A dictionary where the 'nodes' key maps to a list of node dictionaries with 'id' instead of 'name'.
    """
    if not isinstance(data_list, list):
      return data_list # raise TypeError("Input must be a list")

    nodes = []
    for item in data_list:
        if isinstance(item, dict) and 'node' in item and isinstance(item['node'], dict):
            node = item['node'].copy()  # Create a copy to avoid modifying the original
            if 'name' in node:
                node['id'] = node.pop('name')  # Rename 'name' to 'id'
            nodes.append(node)

    return {"nodes": nodes}

restructure_and_rename_nodes(asd)
# Out:
# {'nodes': [{'type': 'TableName', 'id': 'ProspectIncremental'},
#   {'type': 'SchemaName', 'id': 'wh_db_stage'},
#   {'type': 'ColumnName', 'id': 'agencyid'},
#   {'type': 'ColumnName', 'id': 'lastname'},
#   {'type': 'ColumnName', 'id': 'firstname'},
#   {'type': 'ColumnName', 'id': 'middleinitial'},
#   {'type': 'ColumnName', 'id': 'gender'},
#   {'type': 'ColumnName', 'id': 'addressline1'},
#   {'type': 'ColumnName', 'id': 'addressline2'},
#   {'type': 'ColumnName', 'id': 'postalcode'},
#   {'type': 'ColumnName', 'id': 'city'},
#   {'type': 'ColumnName', 'id': 'state'},
#   {'type': 'ColumnName', 'id': 'country'},
#   {'type': 'ColumnName', 'id': 'phone'},
#   {'type': 'ColumnName', 'id': 'income'},
#   {'type': 'ColumnName', 'id': 'numbercars'},
#   {'type': 'ColumnName', 'id': 'numberchildren'},
#   {'type': 'ColumnName', 'id': 'maritalstatus'},
#   {'type': 'ColumnName', 'id': 'age'},
#   {'type': 'ColumnName', 'id': 'creditrating'},
#   {'type': 'ColumnName', 'id': 'ownorrentflag'},
#   {'type': 'ColumnName', 'id': 'employer'},
#   {'type': 'ColumnName', 'id': 'numbercreditcards'},
#   {'type': 'ColumnName', 'id': 'networth'},
#   {'type': 'ColumnName', 'id': 'marketingnameplate'},
#   {'type': 'ColumnName', 'id': 'recordbatchid'},
#   {'type': 'Comment', 'id': 'Unique identifier from agency'},
#   {'type': 'Comment', 'id': 'Last name'},
#   {'type': 'Comment', 'id': 'First name'},
#   {'type': 'Comment', 'id': 'Middle initial'},
#   {'type': 'Comment', 'id': 'â€˜Mâ€™ or â€˜Fâ€™ or â€˜Uâ€™'},
#   {'type': 'Comment', 'id': 'Postal address'},
#   {'type': 'Comment', 'id': 'Postal address'},
#   {'type': 'Comment', 'id': 'Postal code'},
#   {'type': 'Comment', 'id': 'City'},
#   {'type': 'Comment', 'id': 'State or province'},
#   {'type': 'Comment', 'id': 'Postal country'},
#   {'type': 'Comment', 'id': 'Telephone number'},
#   {'type': 'Comment', 'id': 'Annual income'},
#   {'type': 'Comment', 'id': 'Cars owned'},
#   {'type': 'Comment', 'id': 'Dependent children'},
#   {'type': 'Comment',
#    'id': 'â€˜Sâ€™ or â€˜Mâ€™ or â€˜Dâ€™ or â€˜Wâ€™ or â€˜Uâ€™'},
#   {'type': 'Comment', 'id': 'Current age'},
#   {'type': 'Comment', 'id': 'Numeric rating'},
#   {'type': 'Comment', 'id': 'â€˜Oâ€™ or â€˜Râ€™ or â€˜Uâ€™'},
#   {'type': 'Comment', 'id': 'Name of employer'},
#   {'type': 'Comment', 'id': 'Credit cards'},
#   {'type': 'Comment', 'id': 'Estimated total net worth'},
#   {'type': 'Comment', 'id': 'Marketing nameplate'},
#   {'type': 'Comment', 'id': 'Batch ID when this record last inserted'},
#   {'type': 'Summary',
#    'id': 'ProspectIncremental table contains prospect data.'}]}

# %%
def restructure_json_list(data_list):
    """
    Restructures a list of JSON-like dictionaries to group relationships by the 'relationship' key.

    Args:
        data_list: A list of dictionaries, where each dictionary contains a 'relationship' key.

    Returns:
        A dictionary where the 'relationship' key maps to a list of relationship dictionaries.
    """
    if not isinstance(data_list, list):
      return data_list #raise TypeError("Input must be a list")

    nodes = []
    for item in data_list:
        if isinstance(item, dict) and 'node' in item and isinstance(item['node'], dict):
            node = item['node'].copy()  # Create a copy to avoid modifying the original
            if 'name' in node:
                node['id'] = node.pop('name')  # Rename 'name' to 'id'
            nodes.append(node)

    #return {"nodes": nodes}

    relationships = []
    for item in data_list:
        if isinstance(item, dict) and 'relationship' in item and isinstance(item['relationship'], dict):
            relationships.append(item['relationship'])
        #if you have other keys in the original list, you can add more elif statements here.

    return {"nodes": nodes,
        "relationships": relationships}


restructured_data = restructure_json_list(asd2)

restructured_data
# Out:
# {'nodes': [{'id': 'sk_companyid', 'type': 'ColumnName'},
#   {'id': 'Financial', 'type': 'TableName'},
#   {'id': 'BIGINT', 'type': 'Data Type'},
#   {'id': 'wh_db', 'type': 'SchemaName'},
#   {'id': 'Company SK.', 'type': 'Comment'},
#   {'id': 'fi_year', 'type': 'ColumnName'},
#   {'id': 'INT', 'type': 'Data Type'},
#   {'id': 'Year of the quarter end.', 'type': 'Comment'},
#   {'id': 'fi_qtr', 'type': 'ColumnName'},
#   {'id': 'Quarter number that the financial information is for: valid values 1, 2, 3, 4.',
#    'type': 'Comment'},
#   {'id': 'fi_qtr_start_date', 'type': 'ColumnName'},
#   {'id': 'DATE', 'type': 'Data Type'},
#   {'id': 'Start date of quarter.', 'type': 'Comment'},
#   {'id': 'fi_revenue', 'type': 'ColumnName'},
#   {'id': 'DOUBLE', 'type': 'Data Type'},
#   {'id': 'Reported revenue for the quarter.', 'type': 'Comment'},
#   {'id': 'fi_net_earn', 'type': 'ColumnName'},
#   {'id': 'Net earnings reported for the quarter.', 'type': 'Comment'},
#   {'id': 'fi_basic_eps', 'type': 'ColumnName'},
#   {'id': 'Basic earnings per share for the quarter.', 'type': 'Comment'},
#   {'id': 'fi_dilut_eps', 'type': 'ColumnName'},
#   {'id': 'Diluted earnings per share for the quarter.', 'type': 'Comment'},
#   {'id': 'fi_margin', 'type': 'ColumnName'},
#   {'id': 'Profit divided by revenues for the quarter.', 'type': 'Comment'},
#   {'id': 'fi_inventory', 'type': 'ColumnName'},
#   {'id': 'Value of inventory on hand at the end of quarter.',
#    'type': 'Comment'},
#   {'id': 'fi_assets', 'type': 'ColumnName'},
#   {'id': 'Value of total assets at the end of the quarter.',
#    'type': 'Comment'},
#   {'id': 'fi_liability', 'type': 'ColumnName'},
#   {'id': 'Value of total liabilities at the end of the quarter.',
#    'type': 'Comment'},
#   {'id': 'fi_out_basic', 'type': 'ColumnName'},
#   {'id': 'Average number of shares outstanding (basic).', 'type': 'Comment'},
#   {'id': 'fi_out_dilut', 'type': 'ColumnName'},
#   {'id': 'Average number of shares outstanding (diluted).', 'type': 'Comment'},
#   {'id': 'Financial data for companies', 'type': 'Summary'}],
#  'relationships': [{'source': 'sk_companyid',
#    'target': 'Financial',
#    'relation': 'PART_OF'},
#   {'source': 'sk_companyid', 'target': 'BIGINT', 'relation': 'TYPE_OF'},
#   {'source': 'Financial', 'target': 'wh_db', 'relation': 'PART_OF'},
#   {'source': 'Company SK.', 'target': 'sk_companyid', 'relation': 'DESCRIBES'},
#   {'source': 'fi_year', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_year', 'target': 'INT', 'relation': 'TYPE_OF'},
#   {'source': 'Year of the quarter end.',
#    'target': 'fi_year',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_qtr', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_qtr', 'target': 'INT', 'relation': 'TYPE_OF'},
#   {'source': 'Quarter number that the financial information is for: valid values 1, 2, 3, 4.',
#    'target': 'fi_qtr',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_qtr_start_date',
#    'target': 'Financial',
#    'relation': 'PART_OF'},
#   {'source': 'fi_qtr_start_date', 'target': 'DATE', 'relation': 'TYPE_OF'},
#   {'source': 'Start date of quarter.',
#    'target': 'fi_qtr_start_date',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_revenue', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_revenue', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Reported revenue for the quarter.',
#    'target': 'fi_revenue',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_net_earn', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_net_earn', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Net earnings reported for the quarter.',
#    'target': 'fi_net_earn',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_basic_eps', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_basic_eps', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Basic earnings per share for the quarter.',
#    'target': 'fi_basic_eps',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_dilut_eps', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_dilut_eps', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Diluted earnings per share for the quarter.',
#    'target': 'fi_dilut_eps',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_margin', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_margin', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Profit divided by revenues for the quarter.',
#    'target': 'fi_margin',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_inventory', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_inventory', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Value of inventory on hand at the end of quarter.',
#    'target': 'fi_inventory',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_assets', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_assets', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Value of total assets at the end of the quarter.',
#    'target': 'fi_assets',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_liability', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_liability', 'target': 'DOUBLE', 'relation': 'TYPE_OF'},
#   {'source': 'Value of total liabilities at the end of the quarter.',
#    'target': 'fi_liability',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_out_basic', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_out_basic', 'target': 'BIGINT', 'relation': 'TYPE_OF'},
#   {'source': 'Average number of shares outstanding (basic).',
#    'target': 'fi_out_basic',
#    'relation': 'DESCRIBES'},
#   {'source': 'fi_out_dilut', 'target': 'Financial', 'relation': 'PART_OF'},
#   {'source': 'fi_out_dilut', 'target': 'BIGINT', 'relation': 'TYPE_OF'},
#   {'source': 'Average number of shares outstanding (diluted).',
#    'target': 'fi_out_dilut',
#    'relation': 'DESCRIBES'},
#   {'source': 'Financial data for companies',
#    'target': 'Financial',
#    'relation': 'DESCRIBES'}]}

# %%
restructured_data = restructure_json_list(asd2)

restructured_data["nodes"]
# Out:
# [{'id': 'sk_companyid', 'type': 'ColumnName'},
#  {'id': 'Financial', 'type': 'TableName'},
#  {'id': 'BIGINT', 'type': 'Data Type'},
#  {'id': 'wh_db', 'type': 'SchemaName'},
#  {'id': 'Company SK.', 'type': 'Comment'},
#  {'id': 'fi_year', 'type': 'ColumnName'},
#  {'id': 'INT', 'type': 'Data Type'},
#  {'id': 'Year of the quarter end.', 'type': 'Comment'},
#  {'id': 'fi_qtr', 'type': 'ColumnName'},
#  {'id': 'Quarter number that the financial information is for: valid values 1, 2, 3, 4.',
#   'type': 'Comment'},
#  {'id': 'fi_qtr_start_date', 'type': 'ColumnName'},
#  {'id': 'DATE', 'type': 'Data Type'},
#  {'id': 'Start date of quarter.', 'type': 'Comment'},
#  {'id': 'fi_revenue', 'type': 'ColumnName'},
#  {'id': 'DOUBLE', 'type': 'Data Type'},
#  {'id': 'Reported revenue for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_net_earn', 'type': 'ColumnName'},
#  {'id': 'Net earnings reported for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_basic_eps', 'type': 'ColumnName'},
#  {'id': 'Basic earnings per share for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_dilut_eps', 'type': 'ColumnName'},
#  {'id': 'Diluted earnings per share for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_margin', 'type': 'ColumnName'},
#  {'id': 'Profit divided by revenues for the quarter.', 'type': 'Comment'},
#  {'id': 'fi_inventory', 'type': 'ColumnName'},
#  {'id': 'Value of inventory on hand at the end of quarter.',
#   'type': 'Comment'},
#  {'id': 'fi_assets', 'type': 'ColumnName'},
#  {'id': 'Value of total assets at the end of the quarter.', 'type': 'Comment'},
#  {'id': 'fi_liability', 'type': 'ColumnName'},
#  {'id': 'Value of total liabilities at the end of the quarter.',
#   'type': 'Comment'},
#  {'id': 'fi_out_basic', 'type': 'ColumnName'},
#  {'id': 'Average number of shares outstanding (basic).', 'type': 'Comment'},
#  {'id': 'fi_out_dilut', 'type': 'ColumnName'},
#  {'id': 'Average number of shares outstanding (diluted).', 'type': 'Comment'},
#  {'id': 'Financial data for companies', 'type': 'Summary'}]

# %%
for rel in json_data["relationships"]:
    source = rel["source"]
    target = rel["target"]
    relation = rel["relation"]

    query = f"""
    MATCH (s {{id: $source}}), (t {{id: $target}})
    MERGE (s)-[:{relation}]->(t)
    RETURN type(r) AS relation;
    """

    print(query)
# Out:
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:TYPE_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:PART_OF]->(t)
#     RETURN type(r) AS relation;
#
#
#     MATCH (s {id: $source}), (t {id: $target})
#     MERGE (s)-[:DESCRIBES]->(t)
#     RETURN type(r) AS relation;
